# %% [markdown]
# # Save all .oir files in the folder to numpy files

# %%
from oir_loader.utilities import convert_oir_folder

folder_path = r"C:\Users\AB\oir_files"
convert_oir_folder(folder_path, force = False)

# %% [markdown]
# Each .npz file contains both the image and metadata. You can load them in Python using NumPy:
#
# ```python
# import numpy as np
#
# data = np.load("path/to/file.npz", allow_pickle=True)
#
# image = data["image"]
# metadata = data["metadata"]
